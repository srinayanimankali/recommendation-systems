# %%
#1.import the necessary libraries and read the provided CSVs as a data frame and perform the below steps.
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Merge the provided CSVs into one data-frames
#read the csvs
#Loading csv Data files
r1 = pd.read_csv('Data set/phone_user_review_file_1.csv', encoding='iso-8859-1')
r2 = pd.read_csv('Data set/phone_user_review_file_2.csv', encoding='iso-8859-1')
r3 = pd.read_csv('Data set/phone_user_review_file_3.csv', encoding='iso-8859-1')
r4 = pd.read_csv('Data set/phone_user_review_file_4.csv', encoding='iso-8859-1')
r5 = pd.read_csv('Data set/phone_user_review_file_5.csv', encoding='iso-8859-1')
r6 = pd.read_csv('Data set/phone_user_review_file_6.csv', encoding='iso-8859-1')

# %%
#printing head of all the above datasets
r1.head().T
# Out:
#                                                            0  \
# phone_url                     /cellphones/samsung-galaxy-s8/
# date                                                5/2/2017
# lang                                                      en
# country                                                   us
# source                                      Verizon Wireless
# domain                                   verizonwireless.com
# score                                                   10.0
# score_max                                               10.0
# extract    As a diehard Samsung fan who has had every Sam...
# author                                            CarolAnn35
# product                                    Samsung Galaxy S8
#
#                                                            1  \
# phone_url                     /cellphones/samsung-galaxy-s8/
# date                                               4/28/2017
# ...

# %%
r2.head().T
# Out:
#                                                            0  \
# phone_url                         /cellphones/leagoo-lead-7/
# date                                               4/15/2015
# lang                                                      en
# country                                                   us
# source                                                Amazon
# domain                                            amazon.com
# score                                                    2.0
# score_max                                               10.0
# extract    The telephone headset is of poor quality , not...
# author                                                  luis
# product    Leagoo Lead7 5.0 Inch HD JDI LTPS Screen 3G Sm...
#
#                                                            1  \
# phone_url                         /cellphones/leagoo-lead-7/
# date                                               5/23/2015
# ...

# %%
r3.head().T
# Out:
#                                                            0  \
# phone_url    /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/
# date                                               11/7/2015
# lang                                                      pt
# country                                                   br
# source                                             Submarino
# domain                                      submarino.com.br
# score                                                    6.0
# score_max                                               10.0
# extract    recomendo, eu comprei um, a um ano, e agora co...
# author                                      herlington tesch
# product    Samsung Smartphone Samsung Galaxy S3 Slim G381...
#
#                                                            1  \
# phone_url    /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/
# date                                               10/2/2015
# ...

# %%
r4.head().T
# Out:
#                                                            0  \
# phone_url         /cellphones/samsung-s7262-duos-galaxy-ace/
# date                                               3/11/2015
# lang                                                      en
# country                                                   us
# source                                                Amazon
# domain                                            amazon.com
# score                                                    2.0
# score_max                                               10.0
# extract    was not conpatable with my phone as stated. I ...
# author                                      Frances DeSimone
# product    Samsung Galaxy Star Pro DUOS S7262 Unlocked Ce...
#
#                                                            1  \
# phone_url         /cellphones/samsung-s7262-duos-galaxy-ace/
# date                                              17/11/2015
# ...

# %%
r5.head().T
# Out:
#                                                            0  \
# phone_url                         /cellphones/karbonn-k1616/
# date                                               7/13/2016
# lang                                                      en
# country                                                   in
# source                                            91 Mobiles
# domain                                         91mobiles.com
# score                                                    2.0
# score_max                                               10.0
# extract    I bought 1 month before. currently speaker is ...
# author                                             venkatesh
# product                                        Karbonn K1616
#
#                                                            1  \
# phone_url                         /cellphones/karbonn-k1616/
# date                                               7/13/2016
# ...

# %%
r6.head().T
# Out:
#                                                            0  \
# phone_url             /cellphones/samsung-instinct-sph-m800/
# date                                               9/16/2011
# lang                                                      en
# country                                                   us
# source                                           Phone Arena
# domain                                        phonearena.com
# score                                                    8.0
# score_max                                               10.0
# extract    I've had the phone for awhile and it's a prett...
# author                                            ajabrams95
# product                                  Samsung Instinct HD
#
#                                                            1  \
# phone_url             /cellphones/samsung-instinct-sph-m800/
# date                                               2/13/2014
# ...

# %%
#exploring shape and size of each dataset
#r1
shaper1= r1.shape
sizer1= r1.size
print("Shape of r1:",shaper1)
print("Size of r1:",sizer1)
# Out:
# Shape of r1: (374910, 11)
# Size of r1: 4124010

# %%
#r2
shaper2=r2.shape
sizer2=r2.size
print("Shape of r2:",shaper2)
print("Size of r2:",sizer2)
# Out:
# Shape of r2: (114925, 11)
# Size of r2: 1264175

# %%
#r3
shaper3=r3.shape
sizer3=r3.size
print("Shape of r3:",shaper3)
print("Size of r3:",sizer3)
# Out:
# Shape of r3: (312961, 11)
# Size of r3: 3442571

# %%
#r4
shaper4=r4.shape
sizer4=r4.size
print("Shape of r4:",shaper4)
print("Size of r4:",sizer4)
# Out:
# Shape of r4: (98284, 11)
# Size of r4: 1081124

# %%
#r5
shaper5=r5.shape
sizer5=r5.size
print("Shape of r5:",shaper5)
print("Size of r5:",sizer5)
# Out:
# Shape of r5: (350216, 11)
# Size of r5: 3852376

# %%
#r6
shaper6=r6.shape
sizer6=r6.size
print("Shape of r6:",shaper6)
print("Size of r6:",sizer6)
# Out:
# Shape of r6: (163837, 11)
# Size of r6: 1802207

# %%
# 1a. Merge the provided CSVs into one data-frame. 
revdata = pd.concat([r1,r2,r3,r4,r5,r6],axis=0)

# %%
revdata_copy = revdata.copy()

# %%
#attributes
revdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1415133 entries, 0 to 163836
# Data columns (total 11 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   phone_url  1415133 non-null  object
#  1   date       1415133 non-null  object
#  2   lang       1415133 non-null  object
#  3   country    1415133 non-null  object
#  4   source     1415133 non-null  object
#  5   domain     1415133 non-null  object
#  6   score      1351644 non-null  float64
#  7   score_max  1351644 non-null  float64
#  8   extract    1395772 non-null  object
#  9   author     1351931 non-null  object
#  10  product    1415132 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 129.6+ MB

# %%
#1 b. Check a few observations and shape of the data-frame
#shape of the merged dataset
shaped= revdata.shape
print("Shape of the final merged dataset is:",shaped)
# Out:
# Shape of the final merged dataset is: (1415133, 11)

# %%
#size of the merged dataset
sized=revdata.size
print("Size of the final merged dataset is:",sized)
# Out:
# Size of the final merged dataset is: 15566463

# %%
#describe
revdata.describe().T
# Out:
#                count      mean       std   min   25%   50%   75%   max
# score      1351644.0   8.00706  2.616121   0.2   7.2   9.2  10.0  10.0
# score_max  1351644.0  10.00000  0.000000  10.0  10.0  10.0  10.0  10.0

# %% [markdown]
# From the above it is clearly evident that standard deviation from the mean score of 8 is 2.616121

# %%
#head of revdata
revdata.head()
# Out:
#                         phone_url       date lang country            source  \
# 0  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us  Verizon Wireless
# 1  /cellphones/samsung-galaxy-s8/  4/28/2017   en      us       Phone Arena
# 2  /cellphones/samsung-galaxy-s8/   5/4/2017   en      us            Amazon
# 3  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us           Samsung
# 4  /cellphones/samsung-galaxy-s8/  5/11/2017   en      us  Verizon Wireless
#
#                 domain  score  score_max  \
# 0  verizonwireless.com   10.0       10.0
# 1       phonearena.com   10.0       10.0
# 2           amazon.com    6.0       10.0
# 3          samsung.com    9.2       10.0
# 4  verizonwireless.com    4.0       10.0
#
#                                              extract       author  \
# 0  As a diehard Samsung fan who has had every Sam...   CarolAnn35
# 1  Love the phone. the phone is sleek and smooth ...    james0923
# ...

# %%
#check for missing values
revdata.isnull().values.any() # If there are any null values in data set
# Out:
# True

# %%
null_count = revdata.isnull().sum()  # This prints the columns with the number of null values they have
print (null_count)
# Out:
# phone_url        0
# date             0
# lang             0
# country          0
# source           0
# domain           0
# score        63489
# score_max    63489
# extract      19361
# author       63202
# product          1
# dtype: int64

# %%
# 1d. Check for missing values. Impute the missing values if there is any. 
# filling the null values in column 'score' and 'score_max' 
revdata = revdata.fillna(revdata.median())

# dropping the null values in columns 'extract' ,'author' and 'product'
revdata = revdata.dropna()

# %%
# 1c. Round oﬀ scores to the nearest integers. 
revdata['score'] = revdata['score'].astype(int) 
revdata['score_max'] = revdata['score_max'].astype(int)

# %%
#shape of the dataset after dropping null values
revdata.shape
# Out:
# (1336416, 11)

# %%
# 1e. Check for duplicate values and remove them if there is any. 
revdp = revdata.drop_duplicates()

# %%
# 1f. Keep only 1000000 data samples. Use random state=612
df1 = revdp.sample(n=1000000, random_state=612)

# %%
#1g Drop irrelevant features. Keep features like Author, Product, and Score.
#  drop phone_url,date,lang,country,source,domain and extract as they do not contribute in deciding popularity.  
revdp.drop(['phone_url','date','lang','country','source','domain','score_max','extract'], axis = 1, inplace = True)
# Out:
# D:\anaconda\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
rev_c = revdp.copy()

# %%
revdp.shape
# Out:
# (1331600, 3)

# %%
# 1f. Keep only 1000000 data samples. Use random state=612
df4 = revdp.sample(n=1000000, random_state=612)

# %%
# head
df4.head()
# Out:
#         score          author  \
# 104246     10          Paul B
# 78693      10          Yuvraj
# 109329     10   Pankaj Bhalla
# 64164       6        Bgrazina
# 8816        2  Joyce D. Pratt
#
#                                                   product
# 104246  Samsung i897 Captivate Android Smartphone Gala...
# 78693                          Blu Win JR LTE (Grey, 4GB)
# 109329                      Lenovo P780 (Deep Black, 4GB)
# 64164                             Samsung Galaxy XCover 2
# 8816    BLU Vivo XL Smartphone - 5.5" 4G LTE - GSM Unl...

# %%
#df4 shape
df4.shape
# Out:
# (1000000, 3)

# %%
#2.Answer the following questions
#2a.Identify the most rated features.
df4.groupby('product')['score'].mean().sort_values(ascending=False).head()
# Out:
# product
# Smartphone Sony Xperia E1 Desbloqueado Vivo Android 4.3 Tela 4 4GB 3G Wi-Fi CÃ¢mera 3MP - Branco                     10.0
# Samsung Smartphone Samsung Galaxy S5 Desbloqueado Branco Android 4.4.2 4G CÃ¢mera 16 MP MemÃ³ria Interna 16 GB       10.0
# Samsung Smartphone Samsung Galaxy S5 Duos Desbloqueado/ Dual Chip / Branco / 4G / 16 MP / Android 4.4                10.0
# Samsung Smartphone Samsung Galaxy S5 Desbloqueado/ Branco / 4G / 16 MP / Android 4.4.2 / 16 GB / USB 3.0             10.0
# Samsung Smartphone Samsung Galaxy S5 Desbloqueado Vivo Preto Android 4.4.2 4G CÃ¢mera 16 MP MemÃ³ria Interna 16GB    10.0
# Name: score, dtype: float64

# %% [markdown]
# The above are the most rated feature products.

# %%
#2b Identify the users with most number of reviews.
(df4['author'].value_counts()).head()
# Out:
# Amazon Customer    57765
# Cliente Amazon     14564
# e-bit               6309
# Client d'Amazon     5720
# Amazon Kunde        3624
# Name: author, dtype: int64

# %% [markdown]
# The above represents the users/authors with most number of reviews.

# %%
#2c Select the data with products having more than 50 ratings and users who have given more than 50 ratings. Report the shape of the final dataset
#authors who gave greater than 50 ratings
dfr = pd.DataFrame(columns=['author', 'a_count'])
dfr['author']=df4['author'].value_counts().index.tolist() 
dfr['a_count'] = list(df4['author'].value_counts() > 50)

# %%
# get names of indexes for which count column value is False
index_names = dfr[ dfr['a_count'] == False ].index 
# drop these row indexes from dataFrame 
dfr.drop(index_names, inplace = True) 
dfr
# Out:
#               author  a_count
# 0    Amazon Customer     True
# 1     Cliente Amazon     True
# 2              e-bit     True
# 3    Client d'Amazon     True
# 4       Amazon Kunde     True
# ..               ...      ...
# 674           Alexis     True
# 675          eduardo     True
# 676              Ann     True
# 677            elena     True
# 678           mircan     True
#
# [679 rows x 2 columns]

# %%
# extracting product that got more than 50 ratings
df6 = pd.DataFrame(columns=['product', 'p_count'])
df6['product']=df4['product'].value_counts().index.tolist() 
df6['p_count'] = list(df4['product'].value_counts() > 50)

# %%
# get names of indexes for which count column value is False
index_names = df6[ df6['p_count'] == False ].index 
# drop these row indexes from dataFrame 
df6.drop(index_names, inplace = True)

# %%
df6
# Out:
#                                                 product  p_count
# 0                      Lenovo Vibe K4 Note (White,16GB)     True
# 1                     Lenovo Vibe K4 Note (Black, 16GB)     True
# 2                           OnePlus 3 (Graphite, 64 GB)     True
# 3                          OnePlus 3 (Soft Gold, 64 GB)     True
# 4                           Huawei P8lite zwart / 16 GB     True
# ...                                                 ...      ...
# 4341                                          ZTE V880E     True
# 4342                         Sony Ericsson W995 Walkman     True
# 4343  Lenovo Lemon K3 Note 5.5 inch IPS Screen 4G An...     True
# 4344  LG G2 D800 32GB Unlocked GSM 4G LTE 2.26 GHz Q...     True
# 4345  Sony Xperia Z1 Compact Smartphone, schermo 4,3...     True
#
# [4346 rows x 2 columns]

# %%
# selecting rows where product is having more than 50 ratings.  
dr = df4[df4['product'].isin(df6['product'])] 
dr
# Out:
#         score               author  \
# 104246     10               Paul B
# 78693      10               Yuvraj
# 8816        2       Joyce D. Pratt
# 116623     10              David B
# 35333      10            Sebastian
# ...       ...                  ...
# 87173       8               Javier
# 281625      8               Patrix
# 110881      2      Amazon Customer
# 36197      10           majere1975
# 99081      10  ALBERT M. MASSILLON
#
#                                                   product
# 104246  Samsung i897 Captivate Android Smartphone Gala...
# 78693                          Blu Win JR LTE (Grey, 4GB)
# 8816    BLU Vivo XL Smartphone - 5.5" 4G LTE - GSM Unl...
# 116623       Samsung S3350 Chat 335 Sim Free Mobile Phone
# 35333   Samsung E1190 Handy (3,6 cm (1,43 Zoll) Displa...
# ...                                                   ...
# 87173   Huawei Ascend Y330 - Smartphone libre Android ...
# 281625  Huawei Ascend G510 Smartphone Touch, Fotocamer...
# ...

# %%
# selecting data rows from dr where author has given more than 50 ratings.
# 2c. With this we get the data with products having more than 50 ratings and users who have given more than 50 ratings
df8 = dr[dr['author'].isin(dfr['author'])]
df8
# Out:
#         score           author  \
# 35333      10        Sebastian
# 290678      8             sara
# 101404     10   ÐÐ²Ð³ÐµÐ½Ð¸Ð¹
# 223332      8  Amazon Customer
# 361379     10            e-bit
# ...       ...              ...
# 21110       2  Amazon customer
# 321740      8           Qantas
# 269553      9           Capyto
# 87173       8           Javier
# 110881      2  Amazon Customer
#
#                                                   product
# 35333   Samsung E1190 Handy (3,6 cm (1,43 Zoll) Displa...
# 290678  Samsung SM-N910F Galaxy Note 4 Smartphone, 32 ...
# 101404                  Sony Xperia Z1 Compact (Ð»Ð°Ð¹Ð¼)
# 223332  Motorola Moto G 3rd Generation SIM-Free Smartp...
# 361379           Smartphone Motorola Moto G 4 Play XT1603
# ...                                                   ...
# 21110   Tracfone Motorola Moto E Android Prepaid Phone...
# 321740                     Sony Ericsson K810i Cyber-shot
# ...

# %%
# 2c. Report the shape of the final dataset.
df8.shape
# Out:
# (108983, 3)

# %%
#3.Build a popularity based model and recommend top 5 mobile phones.
#calculate the mean score for a product by grouping it.
rmc = pd.DataFrame(df4.groupby('product')['score'].mean())  #rmc= ratings mean count

# %%
# calculating the number of ratings a product got
rmc['rating_counts'] = pd.DataFrame(df4.groupby('product')['score'].count())

# %%
#Recommending the 5 mobile phones based in highest mean score and highest number of ratings the product got. 
rmc.sort_values(by=['score','rating_counts'], ascending=[False,False]).head()
# Out:
#                                                     score  rating_counts
# product
# Samsung Galaxy Note5                                 10.0            144
# Nokia Smartphone Nokia Lumia 520 Desbloqueado O...   10.0            132
# Motorola Smartphone Motorola Moto X Desbloquead...   10.0            131
# Samsung Smartphone Galaxy Win Duos Branco Desbl...   10.0            127
# Motorola Smartphone Motorola Moto G Dual Chip D...   10.0            126

# %% [markdown]
# From the above output, it is clearly evident that the top 5 mobiles are samsung galaxy note5, Nokia Smartphone Nokia Lumia 520 Desbloqueado Oi Preto Windows Phone 8 CÃ¢mera 5MP 3G Wi-Fi MemÃ³ria Interna 8G GPS,Motorola Smartphone Motorola Moto X Desbloqueado Preto Android 4.2.2 CÃ¢mera 10MP e Frontal 2MP MemÃ³ria Interna de 16GB GSM,Samsung Smartphone Galaxy Win Duos Branco Desbloqueado Dual Chip CÃ¢mera 5MP Processador Quad Core 1.2 Ghz Android 4.1 3G Wi- Fi e MemÃ³ria 8GB, and Motorola Smartphone Motorola Moto G Dual Chip Desbloqueado TIM Android 4.3 Tela 4.5 8GB 3G Wi-Fi CÃ¢mera 5MP - Preto

# %%
#4.Build a collaborative filtering model using SVD. You can use SVD from surprise or build it from scratch(Note: Incase you’re building it from scratch you can limit your data points to 5000 samples if you face memory issues). Build a collaborative filtering model using kNNWithMeans from surprise. You can try both user-based and item-based model
# arranging columns in the order of user id,item id and rating to be fed in the svd
columns = ['author','product','score']
vs = rev_c.reindex(columns=columns)

# %%
# Keep only 5000 data samples. Use random state=612
vs_data = vs.sample(n=5000, random_state=612)

# %%
# Build a collaborative filtering model using SVD. 
from surprise import SVD
from surprise import Dataset
from surprise import Reader
reader = Reader(rating_scale=(1, 10))
data = Dataset.load_from_df(vs_data,reader = reader)

# %%
trainset = data.build_full_trainset()

# %%
trainset.ur
# Out:
# defaultdict(list,
#             {0: [(0, 10.0)],
#              1: [(1, 10.0)],
#              2: [(2, 10.0)],
#              3: [(3, 6.0)],
#              4: [(4, 2.0)],
#              5: [(5, 10.0)],
#              6: [(6, 10.0), (1363, 10.0)],
#              7: [(7, 10.0)],
#              8: [(8, 8.0), (465, 9.0)],
#              9: [(9, 8.0)],
#              10: [(10, 10.0)],
#              11: [(11, 2.0)],
#              12: [(12, 8.0)],
#              13: [(13, 8.0)],
#              14: [(14, 10.0)],
#              15: [(15, 10.0)],
#              16: [(16, 2.0)],
#              17: [(17, 8.0)],
#              18: [(18, 10.0)],
#              19: [(19, 9.0)],
#              20: [(20, 8.0)],
#              21: [(21, 10.0),
#               (909, 9.0),
#               (2202, 6.0),
#               (2551, 10.0),
#               (3378, 9.0),
#               (3614, 10.0)],
#              22: [(22, 2.0)],
#              23: [(23, 10.0)],
#              24: [(24, 8.0)],
# ...

# %%
algo = SVD()
algo.fit(trainset)

# %%
#predict ratings for all pairs (u, i) that are NOT in the training set.
testset = trainset.build_anti_testset()

# %%
predictions = algo.test(testset)

# %%
predictions
# Out:
# [Prediction(uid='Paul B', iid='Blu Win JR LTE (Grey, 4GB)', r_ui=8.0086, est=8.370949646400664, details={'was_impossible': False}),
#  Prediction(uid='Paul B', iid='Lenovo P780 (Deep Black, 4GB)', r_ui=8.0086, est=8.229910574998314, details={'was_impossible': False}),
#  Prediction(uid='Paul B', iid='Samsung Galaxy XCover 2', r_ui=8.0086, est=7.943261619051642, details={'was_impossible': False}),
#  Prediction(uid='Paul B', iid='BLU Vivo XL Smartphone - 5.5" 4G LTE - GSM Unlocked - Solid Gold', r_ui=8.0086, est=8.30095000380914, details={'was_impossible': False}),
#  Prediction(uid='Paul B', iid='Samsung S3350 Chat 335 Sim Free Mobile Phone', r_ui=8.0086, est=8.503973711844115, details={'was_impossible': False}),
#  Prediction(uid='Paul B', iid='Samsung E1190 Handy (3,6 cm (1,43 Zoll) Display, Dual-Band) titan gray', r_ui=8.0086, est=8.260425773988796, details={'was_impossible': False}),
# ...

# %%
# 5. Evaluate the collaborative model. Print RMSE value for SVD
print("SVD Model : Test Set")
from surprise import accuracy
accuracy.rmse(predictions, verbose=True)
# Out:
# SVD Model : Test Set
# RMSE: 0.3367
# 0.3366558042775725

# %%
#cross validation
from surprise.model_selection import cross_validate
cross_validate(algo, data, measures=['RMSE'], cv=3, verbose=False)
# Out:
# {'test_rmse': array([2.54135776, 2.60110479, 2.61018606]),
#  'fit_time': (0.23235177993774414, 0.1958327293395996, 0.19347524642944336),
#  'test_time': (0.017943382263183594,
#   0.013589143753051758,
#   0.01793980598449707)}

# %% [markdown]
# RMSE of SVD model is lower than for cross validation.

# %%
def get_Iu(uid): #uid- userid  
     #returns the number of items rated by the user
    try:
        return len(trainset.ur[trainset.to_inner_uid(uid)])
    except ValueError: # user was not part of the trainset
        return 0
    
def get_Ui(iid):#iid- itemid
    #return number of users that have rated given item
    try: 
        return len(trainset.ir[trainset.to_inner_iid(iid)])
    except ValueError:
        return 0
    
bf = pd.DataFrame(predictions, columns=['uid', 'iid', 'rui', 'est', 'details'])
bf['Iu'] = bf.uid.apply(get_Iu)
bf['Ui'] = bf.iid.apply(get_Ui)
bf['err'] = abs(bf.est - bf.rui)
best_predictions = bf.sort_values(by='err')[:10]
worst_predictions = bf.sort_values(by='err')[-10:]

# %%
#best predictions
best_predictions
# Out:
#                      uid                                                iid  \
# 6752215            metin                       Sony Xperia J (ÑÐµÑÐ½ÑÐ¹)
# 12608895           Romac  Samsung G800 Galaxy S5 Mini Smartphone, 16 GB,...
# 13969130         ALESSIO  Samsung Katalyst SGH-T739 No Contract T-Mobile...
# 10792687        Squirt1        Samsung Ch@t 335 Qwerty Mobile Phone (White)
# 2083237             k1ct  Samsung 5-Feet Micro-USB 3.0 Charging Data Cab...
# 7889441       graystroke  Samsung Galaxy S3 mini Smartphone dÃ©bloquÃ© 4...
# 7456755              Liz  LG Electronics L Fino Smartphone (11,4 cm (4,5...
# 10256072  Queen Diva, TX  Dell Venue Pro Phone 8 GB with Windows 7 Opera...
# 7718288          OHennis                              LG Optimus L4 II E440
# 16866776          ruchit  Samsung Galaxy Star S5280 Smartphone (7,6 cm (...
#
#              rui     est                    details  Iu  Ui           err
# ...

# %%
#worst predictions
worst_predictions
# Out:
#                     uid                                                iid  \
# 122296  Amazon Customer                                               M300
# 124332  Amazon Customer  Wiko Rainbow Smartphone WI-FI Bluetooth Androi...
# 123318  Amazon Customer  BLU OnePlus Two 64GB Black, Unlocked Smartphon...
# 122629  Amazon Customer  BLU Vivo Air LTE Smartphone - GSM Unlocked - B...
# 122992  Amazon Customer                                     Sony Xperia SP
# 123902  Amazon Customer                            Samsung Galaxy J3 (8GB)
# 125497  Amazon Customer  Samsung S6810 Galaxy Fame NFC SIM-Free Smartph...
# 122280  Amazon Customer  Sony Xperia L Smartphone (10,9 cm (4,3 Zoll) T...
# 123996  Amazon Customer  Wileyfox Swift 4G Dual SIM-Free Smartphone - W...
# 124249  Amazon Customer         ZTE Warp Android Smartphone (Boost Mobile)
#
#            rui       est                    details   Iu  Ui       err
# 122296  8.0086  5.114734  {'was_impossible': False}  272   1  2.893866
# ...

# %%
#4.Build a collaborative filtering model using kNNWithMeans from surprise. You can try both user-based and item-based model
#item-based
# Read dataset.
reader_1 = Reader(rating_scale=(1, 10))
data_1 = Dataset.load_from_df(vs_data,reader = reader_1)
from surprise.model_selection import train_test_split

# %%
trainset_1, testset_1 = train_test_split(data_1, test_size=.15)

# %%
# Use user_based =false for item based filtering
from surprise import KNNWithMeans
algo_i = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': False})
algo_i.fit(trainset_1)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
# run the  model against the testset
test_pred_1 = algo_i.test(testset_1)

# %%
#6. Predict score (average rating) for test users
#item based
test_pred_1
# Out:
# [Prediction(uid='Amazon Customer', iid='Apple iPhone 6 Unlocked Cellphone, 16GB, Gold', r_ui=2.0, est=10, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Amazon Customer', iid='Lenovo Vibe K4 Note (Black, 16GB)', r_ui=10.0, est=8.432084293217423, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='Michael Buil "Runningman"', iid='BenQ-Siemens EL71 Handy quartz anthracite', r_ui=6.0, est=8.016470588235293, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Bodik', iid='LG P895 Optimus Vu (Black)', r_ui=6.0, est=8.016470588235293, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Florin Radu', iid='Sony Phones XPERIA Tipo Sim Free Mobile Phone - Black', r_ui=10.0, est=8.016470588235293, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
# ...

# %%
#5. get RMSE
print("Item-based Model : Test Set")
accuracy.rmse(test_pred_1, verbose=True)
# Out:
# Item-based Model : Test Set
# RMSE: 2.7078
# 2.707797860451622

# %%
#Build a collaborative filtering model using kNNWithMeans from surprise using User based model
reader_u = Reader(rating_scale=(1, 10))
data_u = Dataset.load_from_df(vs_data,reader = reader_u)

# %%
trainset_u, testset_u = train_test_split(data_u, test_size=.15)

# %%
# Use user_based =true for userbased collaborative filtering
algo_u = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': True})
algo_u.fit(trainset_u)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
# 5. evaluating the model. # we can now query for specific predicions
uid = 'Figarifo'  # raw user id
iid = 'Siemens S65 steel black Handy SIMlock-frei'  # raw item id

# %%
# get a prediction for specific users and items.
pred = algo_u.predict(uid, iid, verbose=True)
# Out:
# user: Figarifo   item: Siemens S65 steel black Handy SIMlock-frei r_ui = None   est = 6.00   {'actual_k': 1, 'was_impossible': False}

# %% [markdown]
# when, author = Figarifo  , item: Siemens S65 steel black Handy SIMlock-frei  estimated rating is 8.03

# %%
# run the trained model against the testset
test_pred_u = algo_u.test(testset_u)

# %%
#5. get RMSE
print("user-based Model : Test Set")
accuracy.rmse(test_pred_u, verbose=True)
# Out:
# user-based Model : Test Set
# RMSE: 2.6848
# 2.6847976410179792

# %%
#6. Predict score (average rating) for test users  # user based
test_pred_u
# Out:
# [Prediction(uid='Daniel Fraga', iid='Apple iPhone 4S 64GB (Black) - Verizon', r_ui=10.0, est=8.03364705882353, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Sampson', iid='Samsung Galaxy Note 5, Black 32GB (Verizon Wireless)', r_ui=10.0, est=8.03364705882353, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='gianpy81', iid='Mitsubishi Trium Astral', r_ui=8.0, est=8.03364705882353, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='HervÃ© Lobry', iid='Samsung I9195 Galaxy S 4 MINI NFC LTE Smartphone Compact', r_ui=8.0, est=8.03364705882353, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='kemoy', iid='Samsung Galaxy Note 4 N910C Unlocked Cellphone, 32GB, Frost White', r_ui=10.0, est=8.03364705882353, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
# ...

# %%
#8.top 5 recommendations for amazon customers uid
pred_1 = pd.DataFrame(test_pred_1)
pred_1[pred_1['uid'] == 'Amazon Customer' ][['iid', 'r_ui','est']].sort_values(by = 'r_ui',ascending = False).head(5)
# Out:
#                                                 iid  r_ui        est
# 324                     Nokia 130 (Dual SIM, Black)  10.0  10.000000
# 279    OnePlus 3T (Gunmetal, 6GB RAM + 64GB memory)  10.0  10.000000
# 534           Micromax Canvas Nitro 4G E455 (Black)  10.0   8.016471
# 510  BLU Studio 6.0 HD - Factory Unlocked ("Black")  10.0   2.000000
# 456   OnePlus 3T (Soft Gold, 6GB RAM + 64GB memory)  10.0   9.507976

# %%
#8.top 5 recommmendations with SVD
pred_2 = pd.DataFrame(predictions)
pred_2[pred_2['uid'] == 'Paul B' ][['iid', 'r_ui','est']].sort_values(by = 'r_ui',ascending = False).head(5)
# Out:
#                                                     iid    r_ui       est
# 0                            Blu Win JR LTE (Grey, 4GB)  8.0086  8.370950
# 2550       Samsung Galaxy S5 SM-G900F 16GB (ÑÐ¸Ð½Ð¸Ð¹)  8.0086  8.265533
# 2538  Smartphone Nokia Lumia 630 Dual Sim Desbloquea...  8.0086  8.325829
# 2539  Sony Mobile Xperia M4 Aqua Smartphone dÃ©bloqu...  8.0086  7.790158
# 2540                              Lenovo IdeaPhone A800  8.0086  8.428924

# %%
#7. Report your findings and inferences

# %% [markdown]
# 1.Samsung Galaxy Note5 is the most popular product Amazon Customer as is the most active author who writes reviews.
#
# 2.Lenovo Vibe K4 Note (White,16GB) was rated by most of the authors CV rmse was 2.5.
#
# 3.User based model has more RMSE value than the item based model.
#
# 4.With used based and item based collaboritive filtering, we can find the top recommended products with the uid and the item id.
#
# 5.With popularity recommendation system, the top products are listed out on the basis of the average rating of the products.
#
# 6.With cross validation on the SVD, user based and item based collaborative filtering the value of RMSE has increased.

# %%
data4 = df4
df4.shape
# Out:
# (1000000, 3)

# %%
#Check for outliers and impute them as required. 
# only score is the column which is numeric so we check it for outliers.
#Checking for outliers in the sample of 1000000
sns.boxplot(x= data4['score'], color='red')
plt.show()
print('Boxplot of score')
#calculating the outiers in attribute 
Q1 = data4['score'].quantile(0.25)
Q2 = data4['score'].quantile(0.50)
Q3 = data4['score'].quantile(0.75) 
IQR = Q3 - Q1
L_W = (Q1 - 1.5 *IQR)
U_W = (Q3 + 1.5 *IQR)    
print('Q1 is : ',Q1)
print('Q2 is : ',Q2)
print('Q3 is : ',Q3)
print('IQR is:',IQR)
print('Lower Whisker, Upper Whisker : ',L_W,',',U_W)
bools = (data4['score'] < (Q1 - 1.5 *IQR)) |(data4['score'] > (Q3 + 1.5 * IQR))
print('number of outliers are:',bools.sum())   #calculating the number of outliers
# Out:
# Boxplot of score
# Q1 is :  8.0
# Q2 is :  9.0
# Q3 is :  10.0
# IQR is: 2.0
# Lower Whisker, Upper Whisker :  5.0 , 13.0
# number of outliers are: 147884

# %%
#function to treat outliers
#Removing outliers by removing data below lower whisker and above upper whisker
Q1 = data4['score'].quantile(0.25)
Q3 = data4['score'].quantile(0.75)
IQR = Q3 - Q1
data4 = data4[(data4['score'] > (Q1 - 1.5 *IQR)) & (data4['score'] < (Q3 + 1.5 *IQR))]
bools = (data4['score'] < (Q1 - 1.5 *IQR)) |(data4['score'] > (Q3 + 1.5 * IQR))
print('number of outliers are:',bools.sum())   #calculating the number of outliers
data4.shape
# Out:
# number of outliers are: 0
# (848829, 3)

# %%
#9. Try cross validation techniques to get better results.
#userbased
cross_validate(algo_u,data_u, measures=['RMSE'], cv=3, verbose=False)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# {'test_rmse': array([2.54446108, 2.66727054, 2.61167627]),
#  'fit_time': (0.19209003448486328, 0.2090303897857666, 0.18920683860778809),
#  'test_time': (0.010963678359985352,
#   0.01694345474243164,
#   0.016942977905273438)}

# %%
#9. Try cross validation techniques to get better results.
#itembased
cross_validate(algo_i,data_1, measures=['RMSE'], cv=3, verbose=False)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# {'test_rmse': array([2.59200469, 2.66901547, 2.65240967]),
#  'fit_time': (0.17478466033935547, 0.24029827117919922, 0.1885817050933838),
#  'test_time': (0.023915529251098633,
#   0.028980255126953125,
#   0.019922733306884766)}

# %% [markdown]
# From the above RMSE values for user and item based models it can be determined that the values of RMSE has increased to 2.67 and 2.67 after applying cross validation for both user and item based colloborative filtering models.

# %%
#10.In what business scenario you should use popularity based Recommendation Systems ?

# %% [markdown]
# Popularity based recommendation systems are based on popularity,trends and frequency counts of which items were most purchased.It can be used when the particular business is a starting stage when they do not know about the customers choice. Using popularity recommendation systems at the initial stage is the best as it helps to overcome coldstart issues.It is used by the following-
#
# 1.travel companies selling holiday packages in a season,
#
# 2.Google News and other news websites to show Top Stories with images.

# %%
#11.In what business scenario you should use CF based Recommendation Systems ?

# %% [markdown]
# Collaborative Filtering is used to building intelligent recommender systems that can learn to give better recommendations as more information about users is collected. It is a personalised recommender system , recommendations are made based on the past behaviour of the user. It is mostly used in websites like Amazon, YouTube, Flipkart and Netflix use collaborative filtering as a part of their sophisticated recommendation system. They are used to suggest new products according to the users choice. For instance, if a person purchases blue jeans he might get a top for recommendation product in the amazon. Hence, the collaborative filtering is very benefitical and useful in business scenarios.

# %%
#12.What other possible methods can you think of which can further improve the recommendation for different users ?

# %% [markdown]
# 1.Content based
#
# 2.Demographic
#
# 3.utility based
#
# 4.knowledge based
#
# 5.hybrid recommendation system
